# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("../data/ManhattanHousing.csv")
data
# Out:
#        BOROUGH               NEIGHBORHOOD  \
# 0            1  ALPHABET CITY
# 1            1  ALPHABET CITY
# 2            1  ALPHABET CITY
# 3            1  ALPHABET CITY
# 4            1  ALPHABET CITY
# 5            1  ALPHABET CITY
# 6            1  ALPHABET CITY
# 7            1  ALPHABET CITY
# 8            1  ALPHABET CITY
# 9            1  ALPHABET CITY
# 10           1  ALPHABET CITY
# 11           1  ALPHABET CITY
# 12           1  ALPHABET CITY
# 13           1  ALPHABET CITY
# 14           1  ALPHABET CITY
# 15           1  ALPHABET CITY
# 16           1  ALPHABET CITY
# 17           1  ALPHABET CITY
# 18           1  ALPHABET CITY
# 19           1  ALPHABET CITY
# 20           1  ALPHABET CITY
# 21           1  ALPHABET CITY
# 22           1  ALPHABET CITY
# 23           1  ALPHABET CITY
# 24           1  ALPHABET CITY
# 25           1  ALPHABET CITY
# 26           1  ALPHABET CITY
# 27           1  ALPHABET CITY
# 28           1  ALPHABET CITY
# ...

# %%
data.isnull().sum()
# Out:
# BOROUGH                           0
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# EASE-MENT                         0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# ZIP CODE                          0
# RESIDENTIAL UNITS                 0
# COMMERCIAL UNITS                  0
# TOTAL UNITS                       0
# LAND SQUARE FEET                  0
# GROSS SQUARE FEET                 0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# SALE PRICE                        0
# SALE DATE                         0
# dtype: int64
